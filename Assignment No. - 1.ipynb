# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df['Age'].unique()
# Out:
# array([34.5 , 47.  , 62.  , 27.  , 22.  , 14.  , 30.  , 26.  , 18.  ,
#        21.  ,   nan, 46.  , 23.  , 63.  , 24.  , 35.  , 45.  , 55.  ,
#         9.  , 48.  , 50.  , 22.5 , 41.  , 33.  , 18.5 , 25.  , 39.  ,
#        60.  , 36.  , 20.  , 28.  , 10.  , 17.  , 32.  , 13.  , 31.  ,
#        29.  , 28.5 , 32.5 ,  6.  , 67.  , 49.  ,  2.  , 76.  , 43.  ,
#        16.  ,  1.  , 12.  , 42.  , 53.  , 26.5 , 40.  , 61.  , 60.5 ,
#         7.  , 15.  , 54.  , 64.  , 37.  , 34.  , 11.5 ,  8.  ,  0.33,
#        38.  , 57.  , 40.5 ,  0.92, 19.  , 36.5 ,  0.75,  0.83, 58.  ,
#         0.17, 59.  , 14.5 , 44.  ,  5.  , 51.  ,  3.  , 38.5 ])

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Age'].nunique()
# Out:
# 79

# %%
df['Fare'].nunique()
# Out:
# 169

# %%
df[['PassengerId','Age']]
# Out:
#      PassengerId   Age
# 0            892  34.5
# 1            893  47.0
# 2            894  62.0
# 3            895  27.0
# 4            896  22.0
# ..           ...   ...
# 413         1305   NaN
# 414         1306  39.0
# 415         1307  38.5
# 416         1308   NaN
# 417         1309   NaN
#
# [418 rows x 2 columns]

# %%
df[df['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# 13                              Howard, Mr. Benjamin    male  63.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
df[df['Age']>40]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 391         1283         1       1
# 393         1285         0       2
# 397         1289         1       1
# 404         1296         0       1
# 407         1299         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']>30) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 14           906         1       1
# 19           911         1       3
# 24           916         1       1
# 32           924         1       3
# 44           936         1       1
# 48           940         1       1
# 49           941         1       3
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 153         1045         1       3
# 178         1070         1       2
# 179         1071         1       1
# 206         1098         1       3
# 208         1100         1       1
# 213         1105         1       2
# 214         1106         1       3
# ...

# %%
df[df['Age'].isin([30, 40])]
# Out:
#      PassengerId  Survived  Pclass  \
# 6            898         1       3
# 34           926         0       1
# 43           935         1       2
# 78           970         0       2
# 139         1031         0       3
# 149         1041         0       2
# 174         1066         0       3
# 180         1072         0       2
# 185         1077         0       2
# 189         1081         0       2
# 220         1112         1       2
# 264         1156         0       2
# 277         1169         0       2
# 278         1170         0       2
# 291         1183         1       3
# 298         1190         0       1
# 306         1198         0       1
# 335         1227         0       1
# 359         1251         1       3
# 400         1292         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                                 Connolly, Miss. Kate  female  30.0      0
# ...

# %%
def Last_no(num):
    return str(num)[-4:]

# %%
df['Ticket'][0]
# Out:
# '330911'

# %%
df['Last_no'] = df['Ticket'].apply(Last_no)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked Last_no
# 0   330911   7.8292   NaN        Q    0911
# 1   363272   7.0000   NaN        S    3272
# 2   240276   9.6875   NaN        Q    0276
# 3   315154   8.6625   NaN        S    5154
# 4  3101298  12.2875   NaN        S    1298

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked Last_no
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S    3236
# 414  39.0      0      0            PC 17758  108.9000  C105        C    7758
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S    1262
# 416   NaN      0      0              359309    8.0500   NaN        S    9309
# 417   NaN      1      1                2668   22.3583   NaN        C    2668

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
#
#     Ticket     Fare Cabin Embarked Last_no
# ...

# %%
df.sort_values('PassengerId')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop(['Age','Sex'], axis=1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  SibSp  Parch   Ticket  \
# 0                              Kelly, Mr. James      0      0   330911
# 1              Wilkes, Mrs. James (Ellen Needs)      1      0   363272
# 2                     Myles, Mr. Thomas Francis      0      0   240276
# 3                              Wirz, Mr. Albert      0      0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1      1  3101298
#
#       Fare Cabin Embarked Last_no
# 0   7.8292   NaN        Q    0911
# 1   7.0000   NaN        S    3272
# 2   9.6875   NaN        Q    0276
# 3   8.6625   NaN        S    5154
# 4  12.2875   NaN        S    1298

# %%
df['Ticket'].value_counts()
# Out:
# PC 17608    5
# CA. 2343    4
# 113503      4
# PC 17483    3
# 220845      3
#            ..
# 349226      1
# 2621        1
# 4133        1
# 113780      1
# 2668        1
# Name: Ticket, Length: 363, dtype: int64

# %%
df = pd.DataFrame(np.arange(0,10).reshape(2,5), index=['Row1','Row2'], columns=['col1','col2','col3','col4','col5'])
df
# Out:
#       col1  col2  col3  col4  col5
# Row1     0     1     2     3     4
# Row2     5     6     7     8     9

# %%
df['col1']
# Out:
# Row1    0
# Row2    5
# Name: col1, dtype: int32

# %%
df[['col1','col2']]
# Out:
#       col1  col2
# Row1     0     1
# Row2     5     6

# %%
df.loc['Row1']
# Out:
# col1    0
# col2    1
# col3    2
# col4    3
# col5    4
# Name: Row1, dtype: int32

# %%
df.iloc[:,0:2]
# Out:
#       col1  col2
# Row1     0     1
# Row2     5     6
